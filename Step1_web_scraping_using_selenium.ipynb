# %%
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

import pandas as pd
import numpy as np

# %%
path = r"C:\Users\Dell\Downloads\edgedriver_win64 (1)\msedgedriver.exe"

# %%
browser = webdriver.Edge(path)

# %%
link = 'https://www.instahyre.com/search-jobs?company_size=0&isLandingPage=true&location=Anywhere+in+India&offset=0&search=true'
browser.get(link)

# %%
parent = browser.current_window_handle

# %%
Job_list = []

for page in range(100):
    print(f'page{page}')
    view_button = browser.find_elements(By.ID, "interested-btn")
    for i in view_button:
        i.click()
        time.sleep(3)
        browser.switch_to.window(browser.window_handles[-1])

        try:
            designation = browser.find_element(By.XPATH, ".//h1[@class = 'ng-binding']").text
        except:
            designation = ''
        try:
            company_name = browser.find_element(By.XPATH, "//*[@id='floating-header']/div[1]/h2").text
        except:
            company_name = ''
        try:
            location = browser.find_element(By.XPATH, ".//*[@id='floating-header']/div[1]/div/span[1]").text
        except:
            location = ''
        try:
            estab_year = browser.find_element(By.XPATH, "(//div[@class='ng-binding ng-scope'])[1]").text
        except:
            estab_year = ''
        try:
            employees_count =  browser.find_element(By.XPATH, "(//div[@class='ng-binding ng-scope'])[2]").text
        except:
            employees_count = ''
        try:
            job_description =  browser.find_element(By.XPATH, ".//p[@class='ng-binding']").text
        except:
            job_description = ''
        try:
            skills = browser.find_element(By.XPATH, "//*[@id='job-skills-description']").text
        except:
            skills = ''
        try:
            hr_name = browser.find_element(By.CLASS_NAME, "rec-info").text
        except:
            hr_name = ''
        try:
            experience_req = browser.find_element(By.XPATH, "//*[@id='floating-header']/div[1]/div/span[2]").text
        except:
            experience_req = ''
        try:
            emp_overall_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[1]/div[2]/span[2]').text
        except:
            emp_overall_rating = ''
        try:
            emp_wl_bal_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[2]/div[2]/span[2]').text
        except:
            emp_wl_bal_rating = ''
        try:
            emp_salary_n_benefits_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[3]/div[2]/span[2]').text
        except:
            emp_salary_n_benefits_rating = ''
        try:
            emp_comp_culture_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[4]/div[2]/span[2]').text
        except:
            emp_comp_culture_rating = ''
        try:
            emp_career_growth_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[5]/div[2]/span[2]').text
        except:
            emp_career_growth_rating = ''
        try:
            emp_diversity_n_inclusion_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[6]/div[2]/span[2]').text
        except:
            emp_diversity_n_inclusion_rating = ''
        try:
            emp_likely_to_recomm_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[7]/div[2]/span[2]').text
        except:
            emp_likely_to_recomm_rating = ''

        job_details = {'designation':designation, 'company_name':company_name,'location':location, 'estab_year':estab_year,
                       'employees_count':employees_count, 'job_description': job_description, 'skills':skills, 'hr_name':hr_name,
                      'experience_req':experience_req, 'emp_overall_rating':emp_overall_rating,'emp_wl_bal_rating':emp_wl_bal_rating,
                      'emp_salary_n_benefits_rating':emp_salary_n_benefits_rating, 'emp_comp_culture_rating':emp_comp_culture_rating,
                      'emp_career_growth_rating':emp_career_growth_rating,'emp_diversity_n_inclusion_rating':emp_diversity_n_inclusion_rating,
                      'emp_likely_to_recomm_rating':emp_likely_to_recomm_rating}

        Job_list.append(job_details)
        browser.close()
        browser.switch_to.window(parent)
        
    next_botton = browser.find_element_by_xpath('//*[@id="job-function-page"]/div[2]/div/div[1]/div[1]/div[11]/li[12]')
    next_botton.click()
    time.sleep(4)
# Out:
# page0
# page1
# page2
# page3
# page4
# page5
# page6
# page7
# page8
# page9
# page10
# page11
# page12
# page13
# page14
# page15
# page16
# page17
# page18
# page19
# page20
# page21
# page22
# page23
# page24
# page25
# page26
# page27
# page28
# page29
# page30
# page31
# page32
# page33
# page34
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9120\325225312.py in <module>
#       5     view_button = browser.find_elements(By.ID, "interested-btn")
#       6     for i in view_button:
# ----> 7         i.click()
#       8         time.sleep(3)
#       9         browser.switch_to.window(browser.window_handles[-1])
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementClickInterceptedException: Message: element click intercepted: Element <button id="interested-btn" class="button-interested btn btn-success" disabled="disabled">...</button> is not clickable at point (775, 18). Other element would receive the click: <a id="nav-user-signup" href="/candidates/register/">...</a>
#   (Session info: MicrosoftEdge=113.0.1774.35)

# %%
df1 = pd.DataFrame(Job_list)
df1

# %%
df1.to_csv("Job_details500.csv")

# %%
df1
# Out:
#                                          designation  \
# 0                        Key Account Manager (Drive)
# 1                                Service Ops (Drive)
# 2                                Brand Sales (Drive)
# 3                        Sr. Revenue Analyst (Drive)
# 4                            Account Manager (Drive)
# 5                Demand Generation Associate (Drive)
# 6                           Process Trainers (Drive)
# 7                     Sr. Operations Analyst (Drive)
# 8                Key Account Manager - Sales (Drive)
# 9                          Operations Intern (Drive)
# 10               Senior Financial Accountant (Drive)
# 11                Fullstack Developer - Java (Drive)
# 12                     Performance Marketing (Drive)
# 13                          Zonal Head Sales (Drive)
# 14                                     DPM 1 (Drive)
# 15                                      QA 1 (Drive)
# 16                                     SDE 1 (Drive)
# 17              Product Marketing Specialist (Drive)
# 18  Software Development Engineer - IV (iOS) (Drive)
# 19                  Senior Software Engineer (Drive)
#
#                          company_name                  location  \
# 0                            Cogoport           Gurgaon, Mumbai
# 1                            Cogoport                   Gurgaon
# 2                              Kutumb         Bangalore, Mumbai
# 3                         RingCentral                 Bangalore
# 4                          SquadStack                     Noida
# 5                          SquadStack          Bangalore, Noida
# 6                          SquadStack            Work From Home
# 7                          SquadStack                     Noida
# 8                              Thence                 Bangalore
# 9                               Zenda  Delhi, Hyderabad, Mumbai
# 10                          EagleView            Work From Home
# 11                        LTIMindtree  Bangalore, Delhi, Mumbai
# 12                            mPokket        Bangalore, Kolkata
# 13        Open Financial Technologies            Chennai, Delhi
# 14  Piramal Capital & Housing Finance                 Bangalore
# 15  Piramal Capital & Housing Finance                    Mumbai
# 16  Piramal Capital & Housing Finance                    Mumbai
# 17                         Univariety                 Hyderabad
# 18                             Upstox                    Mumbai
# 19                              Zynga                 Bangalore
#
#          estab_year           employees_count  \
# 0   Founded in 2016       200 - 500 employees
# 1   Founded in 2016       200 - 500 employees
# 2   Founded in 2020        50 - 200 employees
# 3   Founded in 2003  More than 1000 employees
# 4   Founded in 2014        50 - 200 employees
# 5   Founded in 2014        50 - 200 employees
# 6   Founded in 2014        50 - 200 employees
# 7   Founded in 2014        50 - 200 employees
# 8   Founded in 2012        50 - 200 employees
# 9   Founded in 2021         10 - 50 employees
# 10  Founded in 2008          0 - 10 employees
# 11  Founded in 1996  More than 1000 employees
# 12  Founded in 2016  More than 1000 employees
# 13  Founded in 2017       200 - 500 employees
# 14  Founded in 2017         10 - 50 employees
# 15  Founded in 2017         10 - 50 employees
# 16  Founded in 2017         10 - 50 employees
# 17  Founded in 2011        50 - 200 employees
# 18  Founded in 2010       200 - 500 employees
# 19  Founded in 2007  More than 1000 employees
#
#                                       job_description  \
# 0   Function: Sales and Business → Sales / Busines...
# 1        Function: Operations → Operations Management
# 2   Function: Sales and Business → Sales / Busines...
# 3         Function: Operations → Accounting / Finance
# 4   Function: Sales and Business → Sales / Busines...
# 5              Function: Marketing → Online Marketing
# 6   Function: Sales and Business → Sales / Busines...
# 7        Function: Operations → Operations Management
# 8   Function: Sales and Business → Sales / Busines...
# 9     Function: Sales and Business → Customer Service
# 10        Function: Operations → Accounting / Finance
# 11  Function: Software Engineering → Backend Devel...
# 12             Function: Marketing → Online Marketing
# 13  Function: Sales and Business → Sales / Busines...
# 14  Function: Technical Management → Product Manag...
# 15         Function: Software Engineering → QA / SDET
# 16  Function: Software Engineering → Backend Devel...
# 17             Function: Marketing → Online Marketing
# 18  Function: Software Engineering → Mobile Develo...
# 19  Function: Software Engineering → Full-Stack De...
#
#                                                skills  \
# 0   Corporate Sales\nDirect Sales\nInbound Logisti...
# 1    Data Entry\nDocumentation\nOperations Management
# 2   Brand Management\nBusiness Development\nDigita...
# 3   Accounting\nChartered Accountant\nERP Implemen...
# 4   Key Account Management\nMicrosoft Excel\nSales...
# 5   Business Development\nCRM\nDemand Generation\n...
# 6   BPO Operations\nCorporate Training\nLMS\nSales...
# 7   Data Visualization\nMicrosoft Excel\nOperation...
# 8   Corporate Sales\nKey Account Management\nLinke...
# 9   Customer Interaction\nCustomer Relationship\nC...
# 10  Accounting\nAuditing\nChartered Accountant\nDi...
# 11          Angular\nJava\nMicroservices\nSpring Boot
# 12  Content Marketing\nDigital Marketing\nFacebook...
# 13  Channel Sales\nPayment Processing\nRevenue Man...
# 14                                 Product Management
# 15  Automation Testing\nLMS\nLOS\nManual Testing\n...
# 16  Algorithms\nData Structures\nDjango\nFlask\nJa...
# 17  AB Testing\nAmplitude\nClevertap\nGTM\nGoogle ...
# 18                                Swift\nSwiftUI\niOS
# 19  .NET\nAndroid\nC#\nC++\nJava\nJavaScript\nPyth...
#
#                                               hr_name experience_req  \
# 0   Revati Agnihotri\nManager Talent Acquisition\n...      1-5 Years
# 1   Revati Agnihotri\nManager Talent Acquisition\n...      0-2 Years
# 2                     Dimpy Mehra\nHead HR\nat Kutumb      3-7 Years
# 3    Azhar Ahmed\nTechnical Recruiter\nat RingCentral      2-4 Years
# 4        Marsina Waffa\nTech Recruiter\nat SquadStack      2-5 Years
# 5        Marsina Waffa\nTech Recruiter\nat SquadStack      1-3 Years
# 6        Marsina Waffa\nTech Recruiter\nat SquadStack      1-5 Years
# 7        Marsina Waffa\nTech Recruiter\nat SquadStack      2-4 Years
# 8   Sabari Prasad\nAssistant Manager - Human Resou...      4-8 Years
# 9       Meenal Sharma\nSenior TA Specialist\nat Zenda      0-1 Years
# 10  Kavya Iyer\nTalent Acquisition Specialist\nat ...      3-6 Years
# 11                 Akshata\nRecruiter\nat LTIMindtree      4-6 Years
# 12  Aikya Chakraborty\nTalent Acquisition Manager\...      4-8 Years
# 13  Libin O K\nRecruiter\nat Open Financial Techno...     6-10 Years
# 14       Hr\nHR\nat Piramal Capital & Housing Finance      1-3 Years
# 15       Hr\nHR\nat Piramal Capital & Housing Finance      2-5 Years
# 16       Hr\nHR\nat Piramal Capital & Housing Finance      1-4 Years
# 17         Sunitha Mudiraj\nHR Manager\nat Univariety      2-6 Years
# 18  Asutosh Maharana\nSenior Associate, Talent Acq...     6-10 Years
# 19                Nishtha Pareek\nRecruiter\nat Zynga      5-9 Years
#
#    emp_overall_rating emp_wl_bal_rating emp_salary_n_benefits_rating  \
# 0                 4.2               4.1                          4.3
# 1                 4.2               4.1                          4.3
# 2                 4.9               4.8                          4.9
# 3                 4.6               4.4                          4.6
# 4                   4               3.7                          3.8
# 5                   4               3.7                          3.8
# 6                   4               3.7                          3.8
# 7                   4               3.7                          3.8
# 8                 4.1               3.6                          3.4
# 9                   5                 5                            5
# 10                4.3               3.4                          3.5
# 11                3.8               3.7                          3.3
# 12                4.1               3.7                          3.8
# 13
# 14                4.4               4.1                          4.3
# 15                4.4               4.1                          4.3
# 16                4.4               4.1                          4.3
# 17                3.6               3.4                          3.5
# 18                3.4               3.4                          3.8
# 19                4.5               4.4                          4.3
#
#    emp_comp_culture_rating emp_career_growth_rating  \
# 0                      4.2                      4.3
# 1                      4.2                      4.3
# 2                      4.9                      4.8
# 3                      4.6                      4.6
# 4                      4.2                      4.1
# 5                      4.2                      4.1
# 6                      4.2                      4.1
# 7                      4.2                      4.1
# 8                      3.9                        4
# 9                        5                        5
# 10                     3.5                      3.3
# 11                     3.8                      3.7
# 12                     3.8                      4.1
# 13
# 14                     4.4                      4.4
# 15                     4.4                      4.4
# 16                     4.4                      4.4
# 17                     3.8                      3.7
# 18                     3.5                      3.5
# 19                     4.8                      4.3
#
#    emp_diversity_n_inclusion_rating emp_likely_to_recomm_rating
# 0                               4.2                           4
# 1                               4.2                           4
# 2                               4.8                         4.9
# 3                               4.8                         4.5
# 4                               4.3                           4
# 5                               4.3                           4
# 6                               4.3                           4
# 7                               4.3                           4
# 8                               4.4                         3.5
# 9                                 5                           5
# 10                              3.6                           3
# 11                              3.8                           4
# 12                              4.1                         4.5
# 13
# 14                              4.3                         4.5
# 15                              4.3                         4.5
# 16                              4.3                         4.5
# 17                              3.7                         3.9
# 18                              3.7                         3.6
# 19                              4.6                         4.7
